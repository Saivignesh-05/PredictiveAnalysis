# %% [markdown]
# # GitHub Link For This Project
# **https://github.com/pkroy0185/Breast_Cancer**

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, export_graphviz 
from sklearn.model_selection import train_test_split 
from sklearn import metrics 
from io import StringIO 
from IPython.display import Image  
import pydotplus
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.model_selection import cross_val_score, train_test_split, KFold, StratifiedShuffleSplit, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, log_loss, auc, roc_curve, roc_auc_score, recall_score, precision_recall_curve
from sklearn.metrics import make_scorer, precision_score, fbeta_score, f1_score, classification_report, classification_report
from sklearn.neighbors import KNeighborsClassifier
seed=999

# %% [markdown]
# # Loading Data

# %%
df = pd.DataFrame(load_breast_cancer()['data'], columns=load_breast_cancer()['feature_names'])
df['y'] = load_breast_cancer()['target']
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  y
# 0                  0.2654          0.4601                  0.11890  0
# 1                  0.1860          0.2750                  0.08902  0
# 2                  0.2430          0.3613                  0.08758  0
# 3                  0.2575          0.6638                  0.17300  0
# 4                  0.1625          0.2364                  0.07678  0
# ..                    ...             ...                      ... ..
# 564                0.2216          0.2060                  0.07115  0
# 565                0.1628          0.2572                  0.06637  0
# 566                0.1418          0.2218                  0.07820  0
# 567                0.2650          0.4087                  0.12400  0
# 568                0.0000          0.2871                  0.07039  1
#
# [569 rows x 31 columns]

# %%
X = df.iloc[:,:-1]       # Features
y = df.iloc[:,-1]        # Target variable

# %% [markdown]
# # Splitting Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %% [markdown]
# # Building Decision Tree Model
#    **CRITERION=gini**

# %%
classifier = DecisionTreeClassifier(criterion="gini", max_depth=3)
classifier = classifier.fit(X_train,y_train)

# %% [markdown]
# # Evaluating Model

# %%
y_train_pred = classifier.predict(X_train)
print("Accuracy:",metrics.accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.9748743718592965

# %%
y_pred = classifier.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8830409356725146

# %% [markdown]
# # Visualizing Decision Trees

# %%
dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names=load_breast_cancer()['feature_names'],class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('breast_cancer.png')
Image(graph.create_png())

# %% [markdown]
# # Building Decision Tree Model
# **CRITERION=entropy**

# %%
classifier = DecisionTreeClassifier(criterion="entropy", max_depth=3)
classifier = classifier.fit(X_train,y_train)

# %% [markdown]
# # Evaluating Model

# %%
y_train_pred = classifier.predict(X_train)
print("Accuracy:",metrics.accuracy_score(y_train, y_train_pred))
# Out:
# Accuracy: 0.9698492462311558

# %%
y_pred = classifier.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8830409356725146

# %% [markdown]
# # Visualizing Decision Trees

# %%
dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,  filled=True, rounded=True,special_characters=True, feature_names = load_breast_cancer()['feature_names'],class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('Breast_Cancer1.png')
Image(graph.create_png())

# %% [markdown]
# # RandomForestClassifier

# %% [markdown]
# # Splitting Data

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = .33, stratify = y, random_state = seed)

# %% [markdown]
# # RandomForestClassifier with class_weight

# %%
positive_weight = sum(ytrain == 0) / sum(ytrain == 1)
estimator = RandomForestClassifier(random_state=0, class_weight = {0 : 1, 1 : positive_weight}, warm_start = True)

# %%
rf_tuned_parameters = {"max_depth": [10,20,50,100], 'n_estimators': [50], 'min_samples_leaf': [10,20,50]}

# %%
cv_grid = GridSearchCV(estimator, param_grid = rf_tuned_parameters, scoring = 'roc_auc', verbose = 5) # 'recall', my_score
print(cv_grid.fit(Xtrain, ytrain))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# GridSearchCV(estimator=RandomForestClassifier(class_weight={0: 1,
#                                                             1: 0.5941422594142259},
#                                               random_state=0, warm_start=True),
#              param_grid={'max_depth': [10, 20, 50, 100],
#                          'min_samples_leaf': [10, 20, 50],
#                          'n_estimators': [50]},
#              scoring='roc_auc', verbose=5)

# %%
print(cv_grid.cv_results_)
# Out:
# {'mean_fit_time': array([0.11940694, 0.11913962, 0.10797429, 0.11889133, 0.11418095,
#        0.10954471, 0.1206203 , 0.12180762, 0.1106379 , 0.12168002,
#        0.12083669, 0.11021366]), 'std_fit_time': array([0.00606387, 0.00395178, 0.0045623 , 0.00480109, 0.00375693,
#        0.00413058, 0.00780271, 0.01640143, 0.00575021, 0.00754207,
#        0.00826009, 0.00413497]), 'mean_score_time': array([0.01300426, 0.01287017, 0.01356592, 0.01298347, 0.01294737,
#        0.01313934, 0.01316442, 0.01337905, 0.0133358 , 0.01299262,
#        0.01409869, 0.01361284]), 'std_score_time': array([3.24838027e-04, 5.39763235e-05, 1.10189610e-03, 1.67891282e-04,
#        2.21009748e-04, 7.64988986e-04, 3.90277147e-04, 1.13600248e-03,
#        8.26208186e-04, 1.76446179e-04, 1.88709057e-03, 8.80677938e-04]), 'param_max_depth': masked_array(data=[10, 10, 10, 20, 20, 20, 50, 50, 50, 100, 100, 100],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_min_samples_leaf': masked_array(data=[10, 20, 50, 10, 20, 50, 10, 20, 50, 10, 20, 50],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_n_estimators': masked_array(data=[50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'max_depth': 10, 'min_samples_leaf': 10, 'n_estimators': 50}, {'max_depth': 10, 'min_samples_leaf': 20, 'n_estimators': 50}, {'max_depth': 10, 'min_samples_leaf': 50, 'n_estimators': 50}, {'max_depth': 20, 'min_samples_leaf': 10, 'n_estimators': 50}, {'max_depth': 20, 'min_samples_leaf': 20, 'n_estimators': 50}, {'max_depth': 20, 'min_samples_leaf': 50, 'n_estimators': 50}, {'max_depth': 50, 'min_samples_leaf': 10, 'n_estimators': 50}, {'max_depth': 50, 'min_samples_leaf': 20, 'n_estimators': 50}, {'max_depth': 50, 'min_samples_leaf': 50, 'n_estimators': 50}, {'max_depth': 100, 'min_samples_leaf': 10, 'n_estimators': 50}, {'max_depth': 100, 'min_samples_leaf': 20, 'n_estimators': 50}, {'max_depth': 100, 'min_samples_leaf': 50, 'n_estimators': 50}], 'split0_test_score': array([0.99712644, 0.99640805, 0.99281609, 0.99712644, 0.99640805,
#        0.99281609, 0.99712644, 0.99640805, 0.99281609, 0.99712644,
#        0.99640805, 0.99281609]), 'split1_test_score': array([0.99266324, 0.99119589, 0.98899486, 0.99266324, 0.99119589,
#        0.98899486, 0.99266324, 0.99119589, 0.98899486, 0.99266324,
#        0.99119589, 0.98899486]), 'split2_test_score': array([0.99925595, 0.9985119 , 0.99553571, 0.99925595, 0.9985119 ,
#        0.99553571, 0.99925595, 0.9985119 , 0.99553571, 0.99925595,
#        0.9985119 , 0.99553571]), 'split3_test_score': array([0.96502976, 0.96205357, 0.96354167, 0.96502976, 0.96205357,
#        0.96354167, 0.96502976, 0.96205357, 0.96354167, 0.96502976,
#        0.96205357, 0.96354167]), 'split4_test_score': array([0.98363095, 0.98511905, 0.984375  , 0.98363095, 0.98511905,
#        0.984375  , 0.98363095, 0.98511905, 0.984375  , 0.98363095,
#        0.98511905, 0.984375  ]), 'mean_test_score': array([0.98754127, 0.98665769, 0.98505267, 0.98754127, 0.98665769,
#        0.98505267, 0.98754127, 0.98665769, 0.98505267, 0.98754127,
#        0.98665769, 0.98505267]), 'std_test_score': array([0.01246918, 0.01314471, 0.011392  , 0.01246918, 0.01314471,
#        0.011392  , 0.01246918, 0.01314471, 0.011392  , 0.01246918,
#        0.01314471, 0.011392  ]), 'rank_test_score': array([1, 5, 9, 1, 5, 9, 1, 5, 9, 1, 5, 9], dtype=int32)}

# %% [markdown]
# # Best Parameters

# %%
best_parameters = cv_grid.best_estimator_.get_params()
print(best_parameters)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': {0: 1, 1: 0.5941422594142259}, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 10, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 50, 'n_jobs': None, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': True}

# %%
for param_name in sorted(rf_tuned_parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# 	max_depth: 10
# 	min_samples_leaf: 10
# 	n_estimators: 50

# %% [markdown]
# # Evaluating Model

# %%
pred_test = cv_grid.predict(Xtest)
print(recall_score(ytest, pred_test))     
print(precision_score(ytest, pred_test))  
print(roc_auc_score(ytest, pred_test))   
print("\n confustion matrix on validation data: \n" + str(confusion_matrix(ytest, pred_test)))
# Out:
# 0.9491525423728814
# 0.9739130434782609
# 0.9531476997578694
#
#  confustion matrix on validation data:
# [[ 67   3]
#  [  6 112]]

# %% [markdown]
# # Self-defined Score and GridSearchCV of hyperparameter

# %%
def scoring(ground_truth, predictions):
    '''
    based on results above about the average loss from false positive and false negative predictions.
    '''
    cmatrix = confusion_matrix(ground_truth, predictions)
    fp = cmatrix[0, 1]
    fn = cmatrix[1, 0]
    return  fn * 122 + fp * 1.76
wt_loss_score = make_scorer(scoring, greater_is_better = False)
estimator = RandomForestClassifier(random_state=0, warm_start = True)
rf_tuned_parameters = {"max_depth": [10,20,50,100], 'n_estimators': [50], 'min_samples_leaf': [10,20,50]}
cv_grid = GridSearchCV(estimator, param_grid = rf_tuned_parameters, scoring = wt_loss_score, verbose = 5)
print(cv_grid.fit(Xtrain, ytrain))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 4/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 1/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 3/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 5/5] END max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# GridSearchCV(estimator=RandomForestClassifier(random_state=0, warm_start=True),
#              param_grid={'max_depth': [10, 20, 50, 100],
#                          'min_samples_leaf': [10, 20, 50],
#                          'n_estimators': [50]},
#              scoring=make_scorer(scoring, greater_is_better=False), verbose=5)

# %%
print(cv_grid.best_params_)
# Out:
# {'max_depth': 10, 'min_samples_leaf': 10, 'n_estimators': 50}

# %% [markdown]
# # Best Parameters

# %%
best_parameters = cv_grid.best_estimator_.get_params()
print(best_parameters)
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 10, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 50, 'n_jobs': None, 'oob_score': False, 'random_state': 0, 'verbose': 0, 'warm_start': True}

# %%
for param_name in sorted(rf_tuned_parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# 	max_depth: 10
# 	min_samples_leaf: 10
# 	n_estimators: 50

# %% [markdown]
# # Evaluating Model

# %%
pred_test = cv_grid.predict(Xtest)
print(recall_score(ytest, pred_test))     # 0.84
print(precision_score(ytest, pred_test))  # 0.84
print(roc_auc_score(ytest, pred_test))    # 0.92
print("\n confustion matrix on validation data: \n" + str(confusion_matrix(ytest, pred_test)))
# Out:
# 0.9576271186440678
# 0.9741379310344828
# 0.9573849878934626
#
#  confustion matrix on validation data:
# [[ 67   3]
#  [  5 113]]

# %% [markdown]
# # Gradient Boosting Classifier

# %%
gradient_booster = GradientBoostingClassifier(learning_rate=0.1)
gradient_booster.fit(Xtrain,ytrain)
estimator = GradientBoostingClassifier()
rf_tuned_parameters = {"max_depth": [10, 20, 50, 100], 'n_estimators': [50], 'min_samples_leaf': [10, 20, 50], 'learning_rate': [0.1, 0.01]}

# %%
cv_grid = GridSearchCV(estimator, param_grid = rf_tuned_parameters, scoring = 'roc_auc', verbose = 5) # 'recall', my_score
cv_grid.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.01],
#                          'max_depth': [10, 20, 50, 100],
#                          'min_samples_leaf': [10, 20, 50],
#                          'n_estimators': [50]},
#              scoring='roc_auc', verbose=5)

# %% [markdown]
# # Best Parameters and classification reports

# %%
best_parameters = cv_grid.best_estimator_.get_params()
print(best_parameters)
# Out:
# {'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 100, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 20, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 50, 'n_iter_no_change': None, 'random_state': None, 'subsample': 1.0, 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}

# %%
for param_name in sorted(rf_tuned_parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# 	learning_rate: 0.1
# 	max_depth: 100
# 	min_samples_leaf: 20
# 	n_estimators: 50

# %%
print(classification_report(ytest,gradient_booster.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        70
#            1       0.97      0.99      0.98       118
#
#     accuracy                           0.98       188
#    macro avg       0.98      0.97      0.98       188
# weighted avg       0.98      0.98      0.98       188

# %%
print(classification_report(ytest,cv_grid.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        70
#            1       0.98      0.97      0.97       118
#
#     accuracy                           0.97       188
#    macro avg       0.96      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188

# %% [markdown]
# # Evaluating and visualizing Model

# %%
ypred = cv_grid.predict(Xtest)
fpr, tpr, thresholds = roc_curve(ytest, ypred)
roc_auc = auc(fpr, tpr)
results = confusion_matrix(ytest, ypred)
print ('Confusion Matrix : \n', results)
print ('Accuracy Score is %.4f' % (accuracy_score(ytest, ypred)))
print ('Classification Report : \n', classification_report(ytest, ypred))
print('AUC-ROC:',roc_auc_score(ytest, ypred))
print('LOGLOSS Value is %.4f' % log_loss(ytest, ypred))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'y', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Confusion Matrix :
#  [[ 68   2]
#  [  4 114]]
# Accuracy Score is 0.9681
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        70
#            1       0.98      0.97      0.97       118
#
#     accuracy                           0.97       188
#    macro avg       0.96      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188
#
# AUC-ROC: 0.9687651331719128
# LOGLOSS Value is 1.1023

# %% [markdown]
# # KNN Classifier

# %% [markdown]
# # Generating Model for K=5

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %% [markdown]
# # Model Evaluation for k=5

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9298245614035088
